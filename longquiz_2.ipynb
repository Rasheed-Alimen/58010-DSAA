# %% [markdown]
# <a href="https://colab.research.google.com/github/Rasheed-Alimen/58010-DSAA/blob/main/longquiz_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# G28 = (VG28,EG28)
#
# VG28 =  {E, F, H, I, J, K, M, P}
#
# EG28 = { (H,I), (H,J), (H,K), (I,F), (I,E), (J,E), (J,F), (E,K), (K,F), (M,E), (P,F)}

# %% [markdown]
# ![Screenshot 2023-10-25 085043.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2023-10-25 090018.png](data:image/png;base64,...)

# %%
class graph:
   def __init__(self,gdict=None):
      if gdict is None:
         gdict = []
      self.gdict = gdict

   def getVertices(self):
      return list(self.gdict.keys())

graph_elements = {
   "E" : ["I","J", "K", "M"],
   "F" : ["J", "I", "K", "P"],
   "J" : ["H", "E", "F"],
   "H" : ["J", "K", "I"],
   "I" : ["H", "F", "E"],
   "K" : ["H", "E", "F"],
   "M" : ["E"],
   "P" : ["F"]
}
g = graph(graph_elements)
print(g.getVertices())
# Out:
# ['E', 'F', 'J', 'H', 'I', 'K', 'M', 'P']

# %%
class graph:
   def __init__(self,gdict=None):
      if gdict is None:
         gdict = {}
      self.gdict = gdict

   def edges(self):
      return self.findedges()

   def findedges(self):
      edgename = []
      for vrtx in self.gdict:
         for nxtvrtx in self.gdict[vrtx]:
            if {nxtvrtx, vrtx} not in edgename:
               edgename.append({vrtx, nxtvrtx})
      return edgename

graph_elements = {
    "E" : ["I","J", "K", "M"],
   "F" : ["J", "I", "K", "P"],
   "J" : ["H", "E", "F"],
   "H" : ["J", "K", "I"],
   "I" : ["H", "F", "E"],
   "K" : ["H", "E", "F"],
   "M" : ["E"],
   "P" : ["F"]
}
g = graph(graph_elements)
print(g.edges())
# Out:
# [{'E', 'I'}, {'E', 'J'}, {'E', 'K'}, {'E', 'M'}, {'J', 'F'}, {'I', 'F'}, {'F', 'K'}, {'P', 'F'}, {'J', 'H'}, {'K', 'H'}, {'I', 'H'}]
